# %%
from sklearn import svm
import numpy as np
import pandas as pd
df=pd.read_csv('final_2.csv', sep=',',dtype={'term':str,'emp_length':str,
                                                     'home_ownership':str,'purpose':str,
                                                    'title':str,'earliest_cr_line':str})
df.values
#df.info()
x=df.values[0:10000,1:28]
print(x[:,0].shape)
df.head(1)
# Out:
# (10000,)
#    loan_amnt  funded_amnt  funded_amnt_inv term  int_rate  installment  \
# 0       5000         5000           4975.0   36     10.65       162.87
#
#   emp_length home_ownership  annual_inc    dti     ...       out_prncp_inv  \
# 0         10              1     24000.0  27.65     ...                 0.0
#
#    total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# 0  5861.071414          5831.78           5000.0         861.07
#
#    total_rec_late_fee  recoveries  collection_recovery_fee  last_pymnt_amnt  \
# 0                 0.0         0.0                      0.0           171.62
#
#    loan_status
# 0   Fully Paid
#
# [1 rows x 29 columns]

# %%
y=df.values[0:10000,28]
print(y.shape)
# Out:
# (10000,)

# %%
clf = svm.SVC()
clf.fit(x, y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
#print(x[0])
clf.predict([[5000, 4975.0, '36', 10.65, 162.87, '10', '1', 24000.0, 27.65, 0, 1, 0, 3, 0, 13648,
              83.7, 9, 0.0, 0.0, 5861.071414, 5831.78, 5000.0, 861.07, 0.0, 0.0, 0.0 ,171.62]])
# Out:
# array(['Fully Paid'], dtype=object)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn import svm
import pandas as pd


import matplotlib as mpl
import matplotlib.pyplot as plt


X=x[:,0]
arr1 = X
arr2 = x[:,6]



'''
labl = ['Fully Paid' ,'Charged Off' ,'Current','Current','Current',
        'Fully Paid' ,'Charged Off' ,'Fully Paid' ,'Charged Off' ,'Fully Paid' ]
'''
labl = y
color1= ['green' if l == 'Fully Paid'  else 'red' for l in labl]
plt.xlabel('Loan Amount')
plt.ylabel('Employment Status')
plt.scatter(arr1[0:2000], arr2[0:2000], color=color1)
plt.show()

# %%
X=x[:,0]
arr1 = X
arr2 = x[:,7]



'''
labl = ['Fully Paid' ,'Charged Off' ,'Current','Current','Current',
        'Fully Paid' ,'Charged Off' ,'Fully Paid' ,'Charged Off' ,'Fully Paid' ]
'''
labl = y
color1= ['green' if l == 'Fully Paid'  else 'red' for l in labl]
plt.xlabel('Loan')
plt.ylabel('Home OwnerShip')
plt.scatter(arr1[0:200], arr2[0:200], color=color1)
plt.show()

# %%
X=x[:,0]
arr1 = X
arr2 = x[:,8]



'''
labl = ['Fully Paid' ,'Charged Off' ,'Current','Current','Current',
        'Fully Paid' ,'Charged Off' ,'Fully Paid' ,'Charged Off' ,'Fully Paid' ]
'''
labl = y
color1= ['green' if l == 'Fully Paid'  else 'red' for l in labl]
plt.xlabel('Loan')
plt.ylabel('Income')
plt.scatter(arr1[0:200], arr2[0:200], color=color1)
plt.show()

# %%
X=x[:,0]
arr1 = X
arr2 = x[:,9]



'''
labl = ['Fully Paid' ,'Charged Off' ,'Current','Current','Current',
        'Fully Paid' ,'Charged Off' ,'Fully Paid' ,'Charged Off' ,'Fully Paid' ]
'''
labl = y
color1= ['green' if l == 'Fully Paid'  else 'red' for l in labl]
plt.xlabel('Loan')
plt.ylabel('DTI')
plt.scatter(arr1[0:2000], arr2[0:2000], color=color1)
plt.show()

# %%
X=x[:,0]
arr1 = X
arr2 = x[:,15]



'''
labl = ['Fully Paid' ,'Charged Off' ,'Current','Current','Current',
        'Fully Paid' ,'Charged Off' ,'Fully Paid' ,'Charged Off' ,'Fully Paid' ]
'''
labl = y
color1= ['green' if l == 'Fully Paid'  else 'red' for l in labl]
plt.xlabel('Loan')
plt.ylabel('Revolving Balance')
plt.scatter(arr1[0:200], arr2[0:200], color=color1)
plt.show()

# %%
X=x[:,0]
arr1 = X
arr2 = x[:,16]



'''
labl = ['Fully Paid' ,'Charged Off' ,'Current','Current','Current',
        'Fully Paid' ,'Charged Off' ,'Fully Paid' ,'Charged Off' ,'Fully Paid' ]
'''
labl = y
color1= ['green' if l == 'Fully Paid'  else 'red' for l in labl]
plt.xlabel('Loan')
plt.ylabel('Revolving Utility')
plt.scatter(arr1[0:200], arr2[0:200], color=color1)
plt.show()

# %%
X=x[:,0]
arr1 = X
arr2 = x[:,3]



'''
labl = ['Fully Paid' ,'Charged Off' ,'Current','Current','Current',
        'Fully Paid' ,'Charged Off' ,'Fully Paid' ,'Charged Off' ,'Fully Paid' ]
'''
labl = y
color1= ['green' if l == 'Fully Paid'  else 'red' for l in labl]
plt.xlabel('Loan')
plt.ylabel('Term')
plt.scatter(arr1[0:2000], arr2[0:2000], color=color1,marker='8')
plt.show()

# %%
X=x[:,0]
arr1 = X
arr2 = x[:,4]



'''
labl = ['Fully Paid' ,'Charged Off' ,'Current','Current','Current',
        'Fully Paid' ,'Charged Off' ,'Fully Paid' ,'Charged Off' ,'Fully Paid' ]
'''
labl = y
color1= ['green' if l == 'Fully Paid'  else 'red' for l in labl]
plt.xlabel('Loan')
plt.ylabel('Intrest Rate')
plt.scatter(arr1[0:2000], arr2[0:2000], color=color1,marker='+')
plt.show()
